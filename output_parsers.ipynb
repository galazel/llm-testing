# %%
import config
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import StrOutputParser, CommaSeparatedListOutputParser

# %%
llm = ChatGroq(
    model='llama-3.3-70b-versatile',
    api_key=config.GROQ_API_KEY,
    temperature=0.70
)

# %%
message_h = HumanMessage(content='Give me interesting facts')

# %%
response = llm.invoke([message_h])

# %%
str_output_parser = StrOutputParser()

# %%
response_parsed = str_output_parser.invoke(response)
print(response_parsed)
# Out:
# Here are some interesting facts:
#
# 1. **There's a species of jellyfish that's immortal**: The Turritopsis dohrnii, also known as the "immortal jellyfish," can transform its body into a younger state through a process called transdifferentiation, essentially making it immortal.
#
# 2. **The shortest war in history lasted only 38 minutes**: The Anglo-Zanzibar War between the United Kingdom and Zanzibar on August 27, 1896, is recorded as the shortest war in history, lasting a mere 38 minutes.
#
# 3. **You have a unique tongue print, just like fingerprints**: Just like fingerprints, every person's tongue print is unique and can be used to identify individuals.
#
# 4. **There's a type of fungus that turns ants into "zombies"**: Ophiocordyceps unilateralis, a fungus that infects ants, takes control of their bodies, causing them to climb to high locations and bite onto a leaf before producing fruiting bodies that release spores.
#
# 5. **The human nose can detect over 1 trillion different scents**: Researchers estimate that the human nose can detect an astonishing number of different odors, making our sense of smell incredibly powerful.
#
# 6. **Butterflies taste with their feet**: Butterflies have taste receptors on their feet, which help them detect the sweetness or bitterness of a substance, allowing them to choose the right plants to feed on.
#
# 7. **The longest word in the English language has 45 letters**: The word "pneumonoultramicroscopicsilicovolcanoconiosis" refers to a type of lung disease and is considered the longest word in English.
#
# 8. **There's a lake that's so alkaline it can turn animals into statues**: Lake Natron in Tanzania has such high pH levels that it can calcify the bodies of animals that die in its waters, effectively turning them into statues.
#
# 9. **The world's largest living organism is a fungus**: Armillaria ostoyae, a type of honey mushroom, covers over 2,200 acres in Oregon, USA, and is estimated to be around 2,400 years old.
#
# 10. **You're more likely to die from a falling coconut than a shark attack**: According to statistics, the chances of being killed by a falling coconut are higher than being attacked by a shark.
#
# I hope you find these facts interesting and enjoyable. Is there a specific topic you'd like to learn more about?

# %%
message_h = HumanMessage(content=f'I have a dog but I do not know what name to be given. Can you give me some. {CommaSeparatedListOutputParser().get_format_instructions()}')
response = llm.invoke([message_h])

comma_parser = CommaSeparatedListOutputParser()
comma_parsed = comma_parser.invoke(response)
print(comma_parsed)
# Out:
# ['Max', 'Buddy', 'Charlie', 'Cooper', 'Rocky', 'Bear', 'Duke', 'Oliver', 'Jack', 'Lucy', 'Daisy', 'Luna', 'Bella', 'Gracie', 'Maggie']
